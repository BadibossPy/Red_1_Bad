# %%
import pandas as pd
import json as js
from pandas.io.json import json_normalize
import requests

# %%
my_dic = {'name':'badi',
          'age':23,
         'year':1995}

df = pd.DataFrame.from_dict(my_dic , orient ='index')

# %%
data = js.load(open('RedBed1.json'))
#data['Regions'][0].keys()
#['Cente
#visu =json_normalize(data['Regions'][0]['Centers'])
data['Regions'][0]
# Out:
# {'Name': 'Stockholm',
#  'Centers': [{'Id': '605',
#    'AvailableForOnlineBooking': True,
#    'Name': 'Balance City',
#    'Phone': '08-409 216 79 ',
#    'Email': 'balancecity@sats.se',
#    'Address': 'LÃ¤stmakargatan 10',
#    'City': 'Stockholm',
#    'Zipcode': '111 44 ',
#    'Position': {'Latitude': 59.3355866, 'Longitude': 18.07038209999996},
#    'TeaserImageUrl': '/globalassets/traningscenter/centerbilder/sats/gx/gx2.jpg',
#    'OpeningHours': [{'Day': 'MÃ¥ndag - Torsdag',
#      'Hours': '06:15 - 22:00',
#      'HoursSecond': None},
#     {'Day': 'Fredag', 'Hours': '06:15 - 21:00', 'HoursSecond': None},
#     {'Day': 'LÃ¶rdag - SÃ¶ndag',
#      'Hours': '09:00 - 18:00',
#      'HoursSecond': None}],
#    'OpeningHoursMiniSats': [],
#    'OpeningHoursOther': [{'Day': '1/7 - 28/7:',
#      'Hours': '',
#      'HoursSecond': None},
#     {'Day': 'MÃ¥n - tors\t', 'Hours': '06:30 - 20:00', 'HoursSecond': None},
# ...

# %%
i=0
x=0
for i in range(0,4):
    print(data['Regions'][i]['Name'])
    while x <53 :
        data_norm = json_normalize(data['Regions'][i]['Centers'][x])
        df = 
    i=+1

data_norm
# Out:
#   File "<ipython-input-6-4263544db4cb>", line 7
#     df =
#          ^
# SyntaxError: invalid syntax

# %%
print(data['Regions'][0]['Name'])
# data_norm0 = json_normalize(data['Regions'][0]['Centers'])



OpeningHoursOther = json_normalize(data['Regions'][0]['Centers'][0]['OpeningHoursOther'])
OpeningHoursOther

# Stockholm = pd.DataFrame(data_norm0,columns =['Address', 'AvailableForOnlineBooking', 'City', 'Email', 'Id','MemberActionButton', 'Name', 'OpeningHours',
#        'OpeningHoursMiniSats', 'OpeningHoursOther',
#        'PersonalTrainers', 'Phone', 'Physiotherapists', 'Position.Latitude',
#        'Position.Longitude','Url', 'Zipcode',] )

# Stockholm
# print((data['Regions'][1]['Name']))
# data_norm1 = json_normalize(data['Regions'][1]['Centers'])
# data_norm1

# print((data['Regions'][2]['Name']))
# data_norm_tow = json_normalize(data['Regions'][2]['Centers'])
# data_norm_tow
    
# print((data['Regions'][3]['Name']))
# data_norm3 = json_normalize(data['Regions'][3]['Centers'])
# data_norm3
# Out:
# Stockholm
#               Day          Hours HoursSecond
# 0     1/7 - 28/7:                       None
# 1   MÃ¥n - tors\t  06:30 - 20:00        None
# 2           Fre\t  06:30 - 18:00        None
# 3   LÃ¶r - sÃ¶n\t  10:00 - 15:00        None
# 4                                       None
# 5     29/7 - 4/8:                       None
# 6   MÃ¥n - tors\t  06:30 - 21:00        None
# 7          Fre \t  06:30 - 18:00        None
# 8   LÃ¶r - sÃ¶n\t  10:00 - 15:00        None
# 9                                       None
# 10    5/8 - 18/8:                       None
# 11  MÃ¥n - tors\t  06:30 - 21:00        None
# 12         Fre \t  06:30 - 18:00        None
# 13  LÃ¶r - sÃ¶n\t  10:00 - 18:00        None

# %%
def maniplist(obj,i):
    for ls in obj[:]:
        
def manipdict(dico)


def communinfo(obj ,p ,k) :
    info = data['Regions'][0].keys()
    for key in info
    

    
    
def RedBad(,key):
# Out:
#   File "<ipython-input-21-f4fdb06d99b7>", line 4
#     def manipdict(dico)
#                        ^
# IndentationError: expected an indented block

# %%
data = js.load(open('RedBed1.json'))
df = pd.DataFrame.from_dict(data['Regions'])
df
#for i in range(0,4):
#for item in data['Regions'][1]["Centers"][1]:
           # print(item)
PanData = pd.read_json('RedBed1.json')
print(type(PanData))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
walkdict(data,'Centers')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-9a3f7d872a1d> in <module>
# ----> 1 walkdict(data,'Centers')
#
# NameError: name 'walkdict' is not defined
